# %%
import pandas as pd

# %%
data=pd.read_csv('D:\\PYTHON CODING\\CARD DEFAULT PROJECT\\UCI_Credit_Card.csv')

# %%
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df=data.copy()

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df['SEX'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
df['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0], dtype=int64)

# %%
df['MARRIAGE'].unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
df.EDUCATION.replace(to_replace=[5,6,0],value=4,inplace=True)

# %%
df['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)

# %%
df.MARRIAGE.replace(to_replace=[0],value=3,inplace=True)
# Out:
# C:\Users\AshEdito\AppData\Local\Temp\ipykernel_6988\1760097584.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.MARRIAGE.replace(to_replace=[0],value=3,inplace=True)

# %%
df['MARRIAGE'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df['PAY_AMT1'].dtypes
# Out:
# dtype('float64')

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('default.payment.next.month',axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 X=df.drop('default.payment.next.month',axis=1)
# ----> 2 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=0)
#
# NameError: name 'y' is not defined

# %%
X
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
y=df['default.payment.next.month']

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 30000, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=0)

# %%
X_train
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 15925  15926    30000.0    2          2         2   31     -2     -2     -2
# 10062  10063   200000.0    1          2         1   31      1      2      2
# 19376  19377   500000.0    2          4         2   38     -2     -2     -2
# 6384    6385    20000.0    2          2         2   22      0      0      0
# 15976  15977    50000.0    2          2         1   48      1      2      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 13123  13124    30000.0    1          2         2   38      0      0      0
# 19648  19649   210000.0    2          1         1   33      0      0      0
# 9845    9846   130000.0    2          3         1   43      0      0      0
# 10799  10800    50000.0    2          3         1   29      0      0      0
# 2732    2733   140000.0    2          1         2   25      0      0      0
#
# ...

# %%
y_train
# Out:
# 15925    0
# 10062    0
# 19376    0
# 6384     0
# 15976    1
#         ..
# 13123    0
# 19648    1
# 9845     0
# 10799    0
# 2732     0
# Name: default.payment.next.month, Length: 21000, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lreg=LinearRegression()
lreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lreg_y_pred_train=lreg.predict(X_train)
lreg_y_pred_test=lreg.predict(X_test)

# %%
lreg_y_pred_train
# Out:
# array([-0.02618622,  0.42478476, -0.12216671, ...,  0.23716163,
#         0.22814396,  0.23744863])

# %%
from sklearn.metrics import precision_score,accuracy_score,f1_score,r2_score,mean_absolute_error,mean_squared_error

# %%
accuracy_score(y_train,lreg_y_pred_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 accuracy_score(y_train,lreg_y_pred_train)
#
# File ~\miniconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
# ...

# %%
accuracy_score(y_test,lreg_y_pred_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 accuracy_score(y_test,lreg_y_pred_test)
#
# File ~\miniconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
# ...

# %%
precision_score(y_train,lreg_y_pred_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 precision_score(y_train,lreg_y_pred_train)
#
# File ~\miniconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
# ...

# %%
lreg.score(X,y)
# Out:
# 0.12352179605779767

# %%
list(lreg.coef_)
# Out:
# [3.4426899451832254e-08,
#  -8.671634784310934e-08,
#  -0.018423075112809755,
#  -0.019904919805543167,
#  -0.02916475742818613,
#  0.0013699314668887497,
#  0.08824612885824601,
#  0.02365814102909792,
#  0.011885608934186246,
#  0.0002388696649755347,
#  0.005550490932286715,
#  0.007468092418966863,
#  -6.886895292489474e-07,
#  1.3140595422405927e-07,
#  6.265968942823334e-08,
#  9.482038247442654e-09,
#  -1.1281520065417636e-07,
#  1.9854627381833766e-07,
#  -7.879850725097323e-07,
#  -1.3509270202693846e-07,
#  -2.3315675911955462e-07,
#  -2.4999818283297883e-07,
#  -4.131036720635518e-07,
#  -1.4261396014345122e-07]

# %%
lreg.intercept_
# Out:
# 0.3424792826287476

# %%
r2_score(y_train,lreg_y_pred_train)
# Out:
# 0.12358743810863326

# %%
r2_score(y_test,lreg_y_pred_test)
# Out:
# 0.12312861537693609

# %%
from sklearn.feature_selection import mutual_info_regression
mutual_info=mutual_info_regression(X_train,y_train)
mutual_info
# Out:
# array([0.00404002, 0.01228422, 0.        , 0.        , 0.00652535,
#        0.        , 0.08536001, 0.04510636, 0.03280179, 0.02769731,
#        0.03039304, 0.0230379 , 0.00744345, 0.00340585, 0.0039028 ,
#        0.00508951, 0.01167202, 0.0046407 , 0.02920585, 0.01560486,
#        0.02581647, 0.01574418, 0.01268952, 0.01524781])

# %%
mutual_info=pd.Series(mutual_info)
mutual_info.index=X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# PAY_0        0.085360
# PAY_2        0.045106
# PAY_3        0.032802
# PAY_5        0.030393
# PAY_AMT1     0.029206
# PAY_4        0.027697
# PAY_AMT3     0.025816
# PAY_6        0.023038
# PAY_AMT4     0.015744
# PAY_AMT2     0.015605
# PAY_AMT6     0.015248
# PAY_AMT5     0.012690
# LIMIT_BAL    0.012284
# BILL_AMT5    0.011672
# BILL_AMT1    0.007443
# MARRIAGE     0.006525
# BILL_AMT4    0.005090
# BILL_AMT6    0.004641
# ID           0.004040
# BILL_AMT3    0.003903
# BILL_AMT2    0.003406
# AGE          0.000000
# EDUCATION    0.000000
# SEX          0.000000
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
from sklearn.feature_selection import SelectPercentile

# %%
selected_top_columns=SelectPercentile(mutual_info_regression,percentile=60)
selected_top_columns.fit(X_train,y_train)
# Out:
# SelectPercentile(percentile=60,
#                  score_func=<function mutual_info_regression at 0x000002AD7269E0C0>)

# %%
selected_top_columns.get_support()
# Out:
# array([False,  True, False, False, False, False,  True,  True,  True,
#         True,  True,  True, False, False, False, False,  True,  True,
#         True,  True,  True,  True, False,  True])

# %%
X_train.columns[selected_top_columns.get_support()]
# Out:
# Index(['LIMIT_BAL', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6',
#        'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
#        'PAY_AMT4', 'PAY_AMT6'],
#       dtype='object')

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression(C=1e9,class_weight='balanced')
logreg.fit(X_train,y_train)
# Out:
# C:\Users\AshEdito\miniconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=1000000000.0, class_weight='balanced')

# %%
logreg_y_pred_train = logreg.predict(X_train)
logreg_y_pred_test=logreg.predict(X_test)

# %%
f1_score(y_train,logreg_y_pred_train)
# Out:
# 0.42345763555998256

# %%
f1_score(y_test,logreg_y_pred_test)
# Out:
# 0.40996503496503495

# %%
from sklearn.metrics import f2_score
f2_score(y_train,logreg_y_pred_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 from sklearn.metrics import f2_score
#       2 f2_score(y_train,logreg_y_pred_train)
#
# ImportError: cannot import name 'f2_score' from 'sklearn.metrics' (C:\Users\AshEdito\miniconda3\Lib\site-packages\sklearn\metrics\__init__.py)
